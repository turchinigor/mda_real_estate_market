# %%
import pandas as pd
from pathlib import Path
import json

# %%
test_file = Path.cwd().parent / "data" / "tests" / "listings.json"
with open(test_file, "r") as f:
    data = json.load(f)

# %%
df = pd.DataFrame(data)

# %%
df.shape
# Out:
# (420, 6)

# %%
df = df.dropna(subset=["url"], axis=0)

# %%
df.duplicated(subset=["url"]).sum()
# Out:
# np.int64(0)

# %%
from datetime import date

today = date.today()
print(today)
PATH_URLS = Path(Path.cwd().parent.parent / "data" / "urls" / str(today))
print(PATH_URLS)
# Out:
# 2026-01-28
# /Users/igorturchin/Dev/data/urls/2026-01-28
